# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('C:/Users/prash/Time_series/USA_housing_prices/USA_Housing.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
demand_df = pd.read_csv('C:/Users/prash/Time_series/USA_housing_prices/demand_data.csv')

# %%
demand_df
# Out:
#           DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI
# 0   2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1   2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2   2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3   2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4   2001-01-01       4.23      7.01  13219.251          2.34  110.48
# ..         ...        ...       ...        ...           ...     ...
# 79  2019-10-01       3.60      3.70  19202.310          2.34  212.47
# 80  2020-01-01       3.80      3.52  18951.992          2.36  215.51
# 81  2020-04-01      13.07      3.24  17258.205          2.55  217.89
# 82  2020-07-01       8.80      2.95  18560.774          2.80  222.84
# 83  2020-10-01       6.77      2.76  18767.778          2.74  232.55
#
# [84 rows x 6 columns]

# %%
demand_df['DATE'] = pd.to_datetime(demand_df.DATE)
demand_df
# Out:
#          DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI
# 0  2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1  2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2  2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3  2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4  2001-01-01       4.23      7.01  13219.251          2.34  110.48
# ..        ...        ...       ...        ...           ...     ...
# 79 2019-10-01       3.60      3.70  19202.310          2.34  212.47
# 80 2020-01-01       3.80      3.52  18951.992          2.36  215.51
# 81 2020-04-01      13.07      3.24  17258.205          2.55  217.89
# 82 2020-07-01       8.80      2.95  18560.774          2.80  222.84
# 83 2020-10-01       6.77      2.76  18767.778          2.74  232.55
#
# [84 rows x 6 columns]

# %%
demand_df['year'] = demand_df['DATE'].dt.year
demand_df['month'] = demand_df['DATE'].dt.month
demand_df['day'] = demand_df['DATE'].dt.day
demand_df.head()
# Out:
#         DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI  year  \
# 0 2000-01-01       4.03      8.26  12935.252          1.95  101.34  2000
# 1 2000-04-01       3.93      8.32  13170.749          1.97  103.67  2000
# 2 2000-07-01       4.00      8.02  13183.890          2.09  105.79  2000
# 3 2000-10-01       3.90      7.62  13262.250          2.23  108.27  2000
# 4 2001-01-01       4.23      7.01  13219.251          2.34  110.48  2001
#
#    month  day
# 0      1    1
# 1      4    1
# 2      7    1
# 3     10    1
# 4      1    1

# %%
demand_df.drop(columns=['DATE'],axis = 1,inplace=True)
demand_df.head()
# Out:
#    UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI  year  month  day
# 0       4.03      8.26  12935.252          1.95  101.34  2000      1    1
# 1       3.93      8.32  13170.749          1.97  103.67  2000      4    1
# 2       4.00      8.02  13183.890          2.09  105.79  2000      7    1
# 3       3.90      7.62  13262.250          2.23  108.27  2000     10    1
# 4       4.23      7.01  13219.251          2.34  110.48  2001      1    1

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = demand_df,x="year",y = 'HPI')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = demand_df,x="year",y = 'GDPC1')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
supply_df = pd.read_csv('C:/Users/prash/Time_series/USA_housing_prices/supply_data.csv')

# %%
supply_df
# Out:
#      Unnamed: 0      Period  Permit_Number  construction  Homes_Sold  \
# 0             1  01-01-2000           1727        353065         873
# 1             2  01-02-2000           1692        351933         856
# 2             3  01-03-2000           1651        353452         900
# 3             4  01-04-2000           1597        356188         841
# 4             5  01-05-2000           1543        349907         857
# ..          ...         ...            ...           ...         ...
# 245         246  01-06-2020           1258        553721         840
# 246         247  01-07-2020           1483        575451         979
# 247         248  01-08-2020           1476        615396         977
# 248         249  01-09-2020           1545        619090         965
# 249         250  01-10-2020           1544        637138         945
#
#      Housing_Starts
# 0              1636
# 1              1737
# 2              1604
# 3              1626
# 4              1575
# ...

# %%
supply_df['Period'] = pd.to_datetime(supply_df.Period)
supply_df
# Out:
#      Unnamed: 0     Period  Permit_Number  construction  Homes_Sold  \
# 0             1 2000-01-01           1727        353065         873
# 1             2 2000-01-02           1692        351933         856
# 2             3 2000-01-03           1651        353452         900
# 3             4 2000-01-04           1597        356188         841
# 4             5 2000-01-05           1543        349907         857
# ..          ...        ...            ...           ...         ...
# 245         246 2020-01-06           1258        553721         840
# 246         247 2020-01-07           1483        575451         979
# 247         248 2020-01-08           1476        615396         977
# 248         249 2020-01-09           1545        619090         965
# 249         250 2020-01-10           1544        637138         945
#
#      Housing_Starts
# 0              1636
# 1              1737
# 2              1604
# 3              1626
# 4              1575
# ..              ...
# ...

# %%
supply_df['year'] = supply_df['Period'].dt.year
supply_df['month'] = supply_df['Period'].dt.month
supply_df['day'] = supply_df['Period'].dt.day
supply_df.head()
# Out:
#    Unnamed: 0     Period  Permit_Number  construction  Homes_Sold  \
# 0           1 2000-01-01           1727        353065         873
# 1           2 2000-01-02           1692        351933         856
# 2           3 2000-01-03           1651        353452         900
# 3           4 2000-01-04           1597        356188         841
# 4           5 2000-01-05           1543        349907         857
#
#    Housing_Starts  year  month  day
# 0            1636  2000      1    1
# 1            1737  2000      1    2
# 2            1604  2000      1    3
# 3            1626  2000      1    4
# 4            1575  2000      1    5

# %%
supply_df.drop(columns=['Period'],axis = 1,inplace=True)
supply_df.head()
# Out:
#    Unnamed: 0  Permit_Number  construction  Homes_Sold  Housing_Starts  year  \
# 0           1           1727        353065         873            1636  2000
# 1           2           1692        351933         856            1737  2000
# 2           3           1651        353452         900            1604  2000
# 3           4           1597        356188         841            1626  2000
# 4           5           1543        349907         857            1575  2000
#
#    month  day
# 0      1    1
# 1      1    2
# 2      1    3
# 3      1    4
# 4      1    5

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = supply_df,x="year",y = 'Homes_Sold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,8)) 
sb.lineplot(data = supply_df,x="year",y = 'Homes_Sold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = supply_df,x="year",y = 'construction')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,8)) 
sb.lineplot(data = supply_df,x="year",y = 'construction')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df1 = pd.read_csv('C:/Users/prash/Time_series/USA_housing_prices/Annual_Macroeconomic_Factors.csv')

# %%
df1
# Out:
#           Date  House_Price_Index  Stock_Price_Index  Consumer_Price_Index  \
# 0   1975-01-01            61.0900           67.14653              65.30488
# 1   1976-01-01            65.5250           79.96264              69.05653
# 2   1977-01-01            73.4350           78.82540              73.54636
# 3   1978-01-01            83.7450           78.84679              79.15866
# 4   1979-01-01            95.1325           85.63207              88.06755
# 5   1980-01-01           102.6675          100.00000             100.00000
# 6   1981-01-01           107.2375          108.67516             110.33472
# 7   1982-01-01           108.4600          101.20645             117.09981
# 8   1983-01-01           116.2425          136.01719             120.86156
# 9   1984-01-01           121.4575          135.71240             126.05926
# 10  1985-01-01           127.6625          158.71280             130.52887
# ...

# %%
df1.shape
# Out:
# (47, 9)

# %%
df2 = pd.read_csv('C:/Users/prash/Time_series/USA_housing_prices/Monthly_Macroeconomic_Factors.csv')

# %%
df2.head()
# Out:
#          Date  House_Price_Index  Stock_Price_Index  Consumer_Price_Index  \
# 0  1987-01-01             63.735           14.97068              46.91647
# 1  1987-02-01             64.134           15.86818              47.08523
# 2  1987-03-01             64.470           16.48206              47.29619
# 3  1987-04-01             64.974           16.22884              47.54933
# 4  1987-05-01             65.549           16.14232              47.71810
#
#     Population  Unemployment_Rate  Real_GDP  Mortgage_Rate  \
# 0  153968000.0                6.6   2.41735         9.2040
# 1  154123000.0                6.6   4.57724         9.0825
# 2  154229000.0                6.6   3.87276         9.0350
# 3  154362000.0                6.3   4.83973         9.8325
# 4  154490000.0                6.3   4.51565        10.5960
#
#    Real_Disposable_Income
# 0                  6159.5
# 1                  6192.1
# 2                  6200.0
# 3                  5967.2
# 4                  6209.1

# %%
df2.shape
# Out:
# (423, 9)

# %%
df2['Date'] = pd.to_datetime(df2.Date)
df2
# Out:
#           Date  House_Price_Index  Stock_Price_Index  Consumer_Price_Index  \
# 0   1987-01-01             63.735           14.97068              46.91647
# 1   1987-02-01             64.134           15.86818              47.08523
# 2   1987-03-01             64.470           16.48206              47.29619
# 3   1987-04-01             64.974           16.22884              47.54933
# 4   1987-05-01             65.549           16.14232              47.71810
# ..         ...                ...                ...                   ...
# 418 2021-11-01            276.092          159.94283             117.26923
# 419 2021-12-01            278.681          157.33822             117.62954
# 420 2022-01-01            282.060          158.10031             118.61934
# 421 2022-02-01            287.307          155.27345             119.70281
# 422 2022-03-01            294.717          152.95571             121.30100
#
#       Population  Unemployment_Rate  Real_GDP  Mortgage_Rate  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    423 non-null    datetime64[ns]
#  1   House_Price_Index       423 non-null    float64
#  2   Stock_Price_Index       423 non-null    float64
#  3   Consumer_Price_Index    423 non-null    float64
#  4   Population              423 non-null    float64
#  5   Unemployment_Rate       423 non-null    float64
#  6   Real_GDP                423 non-null    float64
#  7   Mortgage_Rate           423 non-null    float64
#  8   Real_Disposable_Income  423 non-null    float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 29.9 KB

# %%
df2['year'] = df2['Date'].dt.year
df2['month'] = df2['Date'].dt.month
df2['day'] = df2['Date'].dt.day
df2.head()
# Out:
#         Date  House_Price_Index  Stock_Price_Index  Consumer_Price_Index  \
# 0 1987-01-01             63.735           14.97068              46.91647
# 1 1987-02-01             64.134           15.86818              47.08523
# 2 1987-03-01             64.470           16.48206              47.29619
# 3 1987-04-01             64.974           16.22884              47.54933
# 4 1987-05-01             65.549           16.14232              47.71810
#
#     Population  Unemployment_Rate  Real_GDP  Mortgage_Rate  \
# 0  153968000.0                6.6   2.41735         9.2040
# 1  154123000.0                6.6   4.57724         9.0825
# 2  154229000.0                6.6   3.87276         9.0350
# 3  154362000.0                6.3   4.83973         9.8325
# 4  154490000.0                6.3   4.51565        10.5960
#
#    Real_Disposable_Income  year  month  day
# 0                  6159.5  1987      1    1
# 1                  6192.1  1987      2    1
# ...

# %%
df2.drop(columns=['Date'],axis = 1,inplace=True)

# %%
df2.head()
# Out:
#    House_Price_Index  Stock_Price_Index  Consumer_Price_Index   Population  \
# 0             63.735           14.97068              46.91647  153968000.0
# 1             64.134           15.86818              47.08523  154123000.0
# 2             64.470           16.48206              47.29619  154229000.0
# 3             64.974           16.22884              47.54933  154362000.0
# 4             65.549           16.14232              47.71810  154490000.0
#
#    Unemployment_Rate  Real_GDP  Mortgage_Rate  Real_Disposable_Income  year  \
# 0                6.6   2.41735         9.2040                  6159.5  1987
# 1                6.6   4.57724         9.0825                  6192.1  1987
# 2                6.6   3.87276         9.0350                  6200.0  1987
# 3                6.3   4.83973         9.8325                  5967.2  1987
# 4                6.3   4.51565        10.5960                  6209.1  1987
#
#    month  day
# 0      1    1
# 1      2    1
# ...

# %%
plt.figure(figsize=(16,16)) 
sb.barplot(data = df2,x="year",y = 'House_Price_Index')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,16)) 
sb.barplot(data = df2,x="year",y = 'Unemployment_Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,8)) 
sb.lineplot(data = df2,x="year",y = 'Unemployment_Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.regplot(data = df2,x="year",y = 'Unemployment_Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = df2,x="year",y = 'Population')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.lineplot(data = df2,x="year",y = 'Population')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.lineplot(data = df2,x="year",y = 'Mortgage_Rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,10)) 
sb.lineplot(data = df2,x="year",y = 'House_Price_Index')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Real_GDP

plt.figure(figsize=(16,10)) 
sb.lineplot(data = df2,x="year",y = 'Real_GDP')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2.corr()
plt.figure(figsize=(16,16))
plot = sb.heatmap(df2.corr(),cmap='BuPu',annot = True)
plt.show()

# %%
corr_mat = df2.corr(method='pearson')
sorted_mat = corr_mat.unstack().sort_values()
print(sorted_mat)
# Out:
# year                  Mortgage_Rate            -0.955149
# Mortgage_Rate         year                     -0.955149
# Consumer_Price_Index  Mortgage_Rate            -0.952713
# Mortgage_Rate         Consumer_Price_Index     -0.952713
# Population            Mortgage_Rate            -0.948296
#                                                   ...
# day                   Mortgage_Rate                  NaN
#                       Real_Disposable_Income         NaN
#                       year                           NaN
#                       month                          NaN
#                       day                            NaN
# Length: 121, dtype: float64

# %%
cor = df2.corr(method='pearson')
corr_target = abs(cor['House_Price_Index'])

hig_corr_features = corr_target[corr_target>0.90]
hig_corr_features
# Out:
# House_Price_Index         1.000000
# Stock_Price_Index         0.948301
# Consumer_Price_Index      0.934454
# Population                0.904907
# Real_Disposable_Income    0.948260
# year                      0.930179
# Name: House_Price_Index, dtype: float64

# %%
df3 = pd.read_csv('C:/Users/prash/Time_series/USA_housing_prices/Housing_Macroeconomic_Factors_US.csv')

# %%
df3.head()
# Out:
#          Date  house_price_index  population  house_supply        gdp  \
# 0  1987-01-01             63.965      241857           6.0  99.902813
# 1  1987-02-01             64.424      242005           6.2  99.875864
# 2  1987-03-01             64.735      242166           6.0  99.869734
# 3  1987-04-01             65.132      242338           6.0  99.882087
# 4  1987-05-01             65.565      242516           6.7  99.910371
#
#    mortgage_rate  employment_rate  permit_new  ppi_res      m3       cci  \
# 0         9.2040        70.163085      1690.0    100.0  2.7439  100.4624
# 1         9.0825        70.289205      1689.0    100.4  2.7475  100.4945
# 2         9.0350        70.321678      1704.0    100.7  2.7537  100.5720
# 3         9.8325        70.499062      1601.0    101.1  2.7677  100.6568
# 4        10.5960        70.808308      1500.0    101.3  2.7729  100.6919
#
#    delinquency_rate  hcai
# 0               NaN   NaN
# 1               NaN   NaN
# ...

# %%
df3.shape
# Out:
# (425, 13)

# %% [markdown]
# Insights from the data analysis done on some kaggle datasets
# 1. The housing price index has been steadily increasing over time.
# 2. The GDP has also gradually increased over time.
# 3. The number of homes sold increased until 2005 when it sharply decreased before beginning to rise in the following two to three years.
# 4. The cost of building a house follows the same trajectory as the price of dwellings sold.
# 5. The unemployment rate has been on a downward trend over the past two years after reaching its peak in 2011.
# 6. Population growth is consistently rising by a small margin.
# 7. The mortgage rate has gradually fallen since 1990 with just minor ups and downs, but it will begin to rise once more  in 2020 due to inflation.
