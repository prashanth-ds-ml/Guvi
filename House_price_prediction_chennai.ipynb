# %% [markdown]
# # Import libraries and Data
# loading all the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
dataset  = pd.read_csv('train.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
dataset.shape
# Out:
# (7109, 22)

# %%
dataset.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# ...

# %%
dataset.isnull().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
dataset.AREA.value_counts()
# Out:
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chrmpet          6
# Chormpet         6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64

# %%
dataset.loc[dataset['AREA'] == 'Chrompt', 'AREA'] = 'Chrompet'
dataset.loc[dataset['AREA'] == 'Chrmpet', 'AREA'] = 'Chrompet'
dataset.loc[dataset['AREA'] == 'Chormpet', 'AREA'] = 'Chrompet'

dataset.loc[dataset['AREA'] == 'Karapakam', 'AREA'] = 'Karapakkam'

dataset.loc[dataset['AREA'] == 'KKNagar', 'AREA'] = 'KK Nagar'

dataset.loc[dataset['AREA'] == 'Velchery', 'AREA'] = 'Velachery'

dataset.loc[dataset['AREA'] == 'Ann Nagar', 'AREA'] = 'Anna Nagar'
dataset.loc[dataset['AREA'] == 'Ana Nagar', 'AREA'] = 'Anna Nagar'

dataset.loc[dataset['AREA'] == 'Adyr', 'AREA'] = 'Adyar'

dataset.loc[dataset['AREA'] == 'TNagar', 'AREA'] = 'T Nagar'

dataset.AREA.value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
dataset.SALE_COND.value_counts()
# Out:
# AdjLand        1433
# Partial        1429
# Normal Sale    1423
# AbNormal       1406
# Family         1403
# Adj Land          6
# Ab Normal         5
# Partiall          3
# PartiaLl          1
# Name: SALE_COND, dtype: int64

# %%
dataset.loc[dataset['SALE_COND'] == 'Adj Land', 'SALE_COND'] = 'AdjLand'

dataset.loc[dataset['SALE_COND'] == 'Partiall', 'SALE_COND'] = 'Partial'
dataset.loc[dataset['SALE_COND'] == 'PartiaLl', 'SALE_COND'] = 'Partial'

dataset.loc[dataset['SALE_COND'] == 'TNagar', 'SALE_COND'] = 'Normal Sale'

dataset.loc[dataset['SALE_COND'] == 'Ab Normal', 'SALE_COND'] = 'AbNormal'

dataset.SALE_COND.value_counts()
# Out:
# AdjLand        1439
# Partial        1433
# Normal Sale    1423
# AbNormal       1411
# Family         1403
# Name: SALE_COND, dtype: int64

# %%
dataset.PARK_FACIL.value_counts()
# Out:
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64

# %%
dataset.loc[dataset['PARK_FACIL'] == 'Noo', 'PARK_FACIL'] = 'No'

dataset.PARK_FACIL.value_counts()
# Out:
# Yes    3587
# No     3522
# Name: PARK_FACIL, dtype: int64

# %%
dataset.BUILDTYPE.value_counts()
# Out:
# House         2444
# Commercial    2325
# Others        2310
# Other           26
# Comercial        4
# Name: BUILDTYPE, dtype: int64

# %%
dataset.loc[dataset['BUILDTYPE'] == 'Comercial', 'BUILDTYPE'] = 'Commercial'

dataset.loc[dataset['BUILDTYPE'] == 'Other', 'BUILDTYPE'] = 'Others'

dataset.BUILDTYPE.value_counts()
# Out:
# House         2444
# Others        2336
# Commercial    2329
# Name: BUILDTYPE, dtype: int64

# %%
dataset.UTILITY_AVAIL.value_counts()
# Out:
# AllPub     1886
# NoSeWa     1871
# NoSewr     1829
# ELO        1522
# All Pub       1
# Name: UTILITY_AVAIL, dtype: int64

# %%
dataset.loc[dataset['UTILITY_AVAIL'] == 'All Pub', 'UTILITY_AVAIL'] = 'AllPub'

dataset.UTILITY_AVAIL.value_counts()
# Out:
# AllPub     1887
# NoSeWa     1871
# NoSewr     1829
# ELO        1522
# Name: UTILITY_AVAIL, dtype: int64

# %%
dataset.STREET.value_counts()
# Out:
# Paved        2560
# Gravel       2520
# No Access    2010
# Pavd           12
# NoAccess        7
# Name: STREET, dtype: int64

# %%
dataset.loc[dataset['STREET'] == 'Pavd', 'STREET'] = 'Paved'
dataset.loc[dataset['STREET'] == 'NoAccess', 'STREET'] = 'No Access'

dataset.STREET.value_counts()
# Out:
# Paved        2572
# Gravel       2520
# No Access    2017
# Name: STREET, dtype: int64

# %%
dataset.MZZONE.value_counts()
# Out:
# RL    1858
# RH    1822
# RM    1817
# C      550
# A      537
# I      525
# Name: MZZONE, dtype: int64

# %%
df = dataset[dataset.isnull().any(axis = 1)]
df.head()
# Out:
#      PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 15   P06328   Velachery      1868  12-09-2009            148        3.0
# 46   P09483     T Nagar      1882  18-11-2006            189        2.0
# 70   P05304  Anna Nagar      1589  22-03-2010             39        1.0
# 86   P00545    Chrompet      1085  19-01-2014            149        1.0
# 111  P06768       Adyar      1034  30-05-2009             73        1.0
#
#      N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET  \
# 15          2.0       5    Family         No  ...       NoSewr   Gravel
# 46          1.0       5  AbNormal        Yes  ...           ELO  Gravel
# 70          NaN       4   Partial         No  ...        AllPub  Gravel
# 86          1.0       3  AbNormal        Yes  ...       NoSewr   Gravel
# 111         1.0       3   AdjLand        Yes  ...           ELO  Gravel
#
#     MZZONE QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  \
# ...

# %%
mean_bedroom = dataset['N_BEDROOM'].mean()
mean_bathroom = dataset['N_BATHROOM'].mean()
mean_qs = dataset['QS_OVERALL'].mean()
dataset['N_BEDROOM'].fillna(value = mean_bedroom, inplace = True)
dataset['N_BATHROOM'].fillna(value = mean_bathroom, inplace = True)
dataset['QS_OVERALL'].fillna(value = mean_qs, inplace = True)

# %%
dataset.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DATE_SALE        0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# DATE_BUILD       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# REG_FEE          0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
df_dt = pd.DataFrame(dataset,columns = ['DATE_SALE','DATE_BUILD'])

# %%
df_dt['DATE_SALE'] = pd.to_datetime(df_dt.DATE_SALE)
df_dt['DATE_BUILD'] = pd.to_datetime(df_dt.DATE_BUILD)

# %%
df_dt['Date_sale_year'] = df_dt['DATE_SALE'].dt.year
df_dt['Date_sale_month'] = df_dt['DATE_SALE'].dt.month
df_dt['Date_sale_day'] = df_dt['DATE_SALE'].dt.day

df_dt['Date_Build_year'] = df_dt['DATE_BUILD'].dt.year
df_dt['Date_Build_month'] = df_dt['DATE_BUILD'].dt.month
df_dt['Date_Build_day'] = df_dt['DATE_BUILD'].dt.day

# %%
df_dt.head()
# Out:
#    DATE_SALE DATE_BUILD  Date_sale_year  Date_sale_month  Date_sale_day  \
# 0 2011-04-05 1967-05-15            2011                4              5
# 1 2006-12-19 1995-12-22            2006               12             19
# 2 2012-04-02 1992-09-02            2012                4              2
# 3 2010-03-13 1988-03-18            2010                3             13
# 4 2009-05-10 1979-10-13            2009                5             10
#
#    Date_Build_year  Date_Build_month  Date_Build_day
# 0             1967                 5              15
# 1             1995                12              22
# 2             1992                 9               2
# 3             1988                 3              18
# 4             1979                10              13

# %%
df_dt = df_dt.drop(columns=['DATE_SALE','DATE_BUILD'])

# %%
df_dt.head()
# Out:
#    Date_sale_year  Date_sale_month  Date_sale_day  Date_Build_year  \
# 0            2011                4              5             1967
# 1            2006               12             19             1995
# 2            2012                4              2             1992
# 3            2010                3             13             1988
# 4            2009                5             10             1979
#
#    Date_Build_month  Date_Build_day
# 0                 5              15
# 1                12              22
# 2                 9               2
# 3                 3              18
# 4                10              13

# %%
df = pd.concat([df_dt,dataset],axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date_sale_year    7109 non-null   int64
#  1   Date_sale_month   7109 non-null   int64
#  2   Date_sale_day     7109 non-null   int64
#  3   Date_Build_year   7109 non-null   int64
#  4   Date_Build_month  7109 non-null   int64
#  5   Date_Build_day    7109 non-null   int64
#  6   PRT_ID            7109 non-null   object
#  7   AREA              7109 non-null   object
#  8   INT_SQFT          7109 non-null   int64
#  9   DATE_SALE         7109 non-null   object
#  10  DIST_MAINROAD     7109 non-null   int64
#  11  N_BEDROOM         7109 non-null   float64
#  12  N_BATHROOM        7109 non-null   float64
#  13  N_ROOM            7109 non-null   int64
#  14  SALE_COND         7109 non-null   object
#  15  PARK_FACIL        7109 non-null   object
# ...

# %%
df = df.drop(columns=['DATE_SALE','DATE_BUILD'])

# %%
df.shape
# Out:
# (7109, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date_sale_year    7109 non-null   int64
#  1   Date_sale_month   7109 non-null   int64
#  2   Date_sale_day     7109 non-null   int64
#  3   Date_Build_year   7109 non-null   int64
#  4   Date_Build_month  7109 non-null   int64
#  5   Date_Build_day    7109 non-null   int64
#  6   PRT_ID            7109 non-null   object
#  7   AREA              7109 non-null   object
#  8   INT_SQFT          7109 non-null   int64
#  9   DIST_MAINROAD     7109 non-null   int64
#  10  N_BEDROOM         7109 non-null   float64
#  11  N_BATHROOM        7109 non-null   float64
#  12  N_ROOM            7109 non-null   int64
#  13  SALE_COND         7109 non-null   object
#  14  PARK_FACIL        7109 non-null   object
#  15  BUILDTYPE         7109 non-null   object
# ...

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = df,x="Date_sale_year",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,10)) 
sb.regplot(data = df,x="INT_SQFT",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,10)) 
sb.lineplot(data = df,x="Date_sale_year",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,10)) 
sb.lineplot(data = df,x="Date_sale_month",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = df,x="Date_sale_month",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = df,x="N_BEDROOM",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,10)) 
sb.barplot(data = df,x="N_ROOM",y = 'SALES_PRICE')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.corr()
plt.figure(figsize=(16,16))
plot = sb.heatmap(df.corr(),cmap='BuPu',annot = True)
plt.show()

# %%
def scatter(df, column):
    plt.figure(figsize=(10,10))
    plt.scatter(dataset[column] , dataset['SALES_PRICE'])
    plt.ylabel('SALES_PRICE')
    plt.xlabel(column)

# %%
scatter(dataset, 'AREA')
scatter(dataset, 'INT_SQFT')
scatter(dataset, 'DIST_MAINROAD')
scatter(dataset, 'N_BEDROOM')
scatter(dataset, 'N_BATHROOM')
scatter(dataset, 'N_ROOM')
scatter(dataset, 'SALE_COND')
scatter(dataset, 'REG_FEE')
scatter(dataset, 'COMMIS')

# %%
area_names = df['AREA'].value_counts()[0:10].keys()
area_names
# Out:
# Index(['Chrompet', 'Karapakkam', 'KK Nagar', 'Velachery', 'Anna Nagar',
#        'Adyar', 'T Nagar'],
#       dtype='object')

# %%
area_sales = df[['AREA','SALES_PRICE']]
area_sales
# Out:
#             AREA  SALES_PRICE
# 0     Karapakkam      7600000
# 1     Anna Nagar     21717770
# 2          Adyar     13159200
# 3      Velachery      9630290
# 4     Karapakkam      7406250
# ...          ...          ...
# 7104  Karapakkam      5353000
# 7105   Velachery     10818480
# 7106   Velachery      8351410
# 7107  Karapakkam      8507000
# 7108   Velachery      9976480
#
# [7109 rows x 2 columns]

# %%
area_sales = area_sales.sort_values(by=['SALES_PRICE'],ascending = True)
area_sales.head(20)
# Out:
#             AREA  SALES_PRICE
# 3385  Karapakkam      2156875
# 1336  Karapakkam      2476375
# 2369  Karapakkam      2640250
# 2986  Karapakkam      2797250
# 1488  Karapakkam      2939750
# 2251  Karapakkam      3000375
# 2972  Karapakkam      3001250
# 550   Karapakkam      3013500
# 4929  Karapakkam      3029750
# 6667  Karapakkam      3081375
# 6797  Karapakkam      3090250
# 1376  Karapakkam      3093500
# 3990  Karapakkam      3102500
# 3134  Karapakkam      3120000
# 6783  Karapakkam      3172500
# 5225  Karapakkam      3189500
# 3893  Karapakkam      3210125
# 4276  Karapakkam      3219750
# 4241  Karapakkam      3226250
# 3360  Karapakkam      3247750

# %%
area_sales_asf = area_sales.sort_values(by=['SALES_PRICE'],ascending = False)
area_sales_asf.head(20)
# Out:
#             AREA  SALES_PRICE
# 837      T Nagar     23667340
# 6336  Anna Nagar     23407860
# 6164  Anna Nagar     23314580
# 125      T Nagar     23307000
# 4779     T Nagar     23247590
# 7076     T Nagar     23013500
# 2974     T Nagar     22918500
# 1099  Anna Nagar     22916500
# 3202     T Nagar     22852890
# 572   Anna Nagar     22829130
# 2927  Anna Nagar     22778410
# 638   Anna Nagar     22744800
# 6348     T Nagar     22726060
# 3242  Anna Nagar     22712170
# 5234     T Nagar     22686330
# 4309  Anna Nagar     22633000
# 168      T Nagar     22630540
# 7000     T Nagar     22629400
# 5346  Anna Nagar     22619470
# 5674  Anna Nagar     22593290

# %%
plt.figure(figsize=(8,10))
plt.bar(list(area_sales_asf['AREA'])[0:5],list(area_sales_asf['SALES_PRICE'])[0:5],color = 'g')
plt.show()

# %%
anna_nagar = df[df['AREA'] == 'Anna Nagar']
anna_nagar.head()
# Out:
#     Date_sale_year  Date_sale_month  Date_sale_day  Date_Build_year  \
# 1             2006               12             19             1995
# 19            2012                2              7             1970
# 30            2009                1              4             2000
# 34            2009               11             22             2003
# 47            2009               12             11             1998
#
#     Date_Build_month  Date_Build_day  PRT_ID        AREA  INT_SQFT  \
# 1                 12              22  P09411  Anna Nagar      1986
# 19                 7              13  P01372  Anna Nagar      1902
# 30                 3               4  P06980  Anna Nagar      1981
# 34                11              24  P05950  Anna Nagar      1709
# 47                11              15  P06006  Anna Nagar      1710
#
#     DIST_MAINROAD  ...  UTILITY_AVAIL     STREET  MZZONE QS_ROOMS QS_BATHROOM  \
# ...

# %%
anna_nagara_yearwise = anna_nagar[['Date_sale_year','SALES_PRICE']]
anna_nagara_yearwise
# Out:
#       Date_sale_year  SALES_PRICE
# 1               2006     21717770
# 19              2012     21203240
# 30              2009     12872430
# 34              2009     12928590
# 47              2009     20215970
# ...              ...          ...
# 7070            2012     11383690
# 7078            2014     13174060
# 7095            2007     13308750
# 7097            2010     14111320
# 7098            2013     13944780
#
# [788 rows x 2 columns]

# %%
anna_nagara_yearwise = anna_nagara_yearwise.sort_values(by=['Date_sale_year'],ascending = False)
anna_nagara_yearwise.head(20)
# Out:
#       Date_sale_year  SALES_PRICE
# 5693            2015     13390780
# 2935            2015     19462090
# 2017            2015     19844870
# 1273            2015     11618510
# 2830            2015     11412420
# 2576            2015     14565090
# 6565            2015     19871700
# 3296            2015     15778370
# 3376            2015     14993570
# 1754            2015     14904220
# 1761            2015     20346350
# 489             2015     17566590
# 665             2015     12053080
# 3238            2015     20938520
# 4968            2015     15132260
# 6164            2015     23314580
# 4931            2014     12836660
# 4940            2014     12570050
# 5720            2014     12627130
# 4921            2014     12571020

# %%
anna_nagara_yearwise_count = anna_nagara_yearwise['Date_sale_year'].value_counts()[0:].keys()
anna_nagara_yearwise_count
# Out:
# Int64Index([2007, 2011, 2009, 2008, 2013, 2012, 2014, 2010, 2015, 2006], dtype='int64')

# %%
plt.figure(figsize=(16,8))
plt.bar(list(anna_nagara_yearwise_count),anna_nagara_yearwise['Date_sale_year'].value_counts()[0:],color = ['orange'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
lb_res = lb.fit_transform(df['AREA'])
df_1 = pd.DataFrame(lb_res,columns = lb.classes_)

# %%
df_1.head()

# %%
lb_res = lb.fit_transform(df['SALE_COND'])
df_2 = pd.DataFrame(lb_res,columns = lb.classes_)
df_2.head()

# %%
lb_res = lb.fit_transform(df['BUILDTYPE'])
df_3 = pd.DataFrame(lb_res,columns = lb.classes_)
df_3.head()

# %%
lb_res = lb.fit_transform(df['UTILITY_AVAIL'])
df_4 = pd.DataFrame(lb_res,columns = lb.classes_)
df_4.head()

# %%
lb_res = lb.fit_transform(df['STREET'])
df_5 = pd.DataFrame(lb_res,columns = lb.classes_)
df_5.head()

# %%
lb_res = lb.fit_transform(df['MZZONE'])
df_6 = pd.DataFrame(lb_res,columns = lb.classes_)
df_6.head()

# %%
df_7 = pd.get_dummies(df,columns = ['PARK_FACIL'])
df_7.head()

# %%
df_tra = pd.concat([df_7,df_1,df_2,df_3,df_4,df_5,df_6],axis=1)

# %%
df_tra

# %%
df_tra.head()

# %%
df_train = df_tra.drop(columns = ['PRT_ID','AREA','SALE_COND','BUILDTYPE','UTILITY_AVAIL','STREET','MZZONE'])

# %%
df_train.info()

# %%
column = df_train.pop('SALES_PRICE')

# %%
df_train.insert(47, 'SALES_PRICE', column)

# %%
df_train.info()

# %%
df_train.describe()

# %%
x = df_train.iloc[:,0:47]
x

# %%
y = df_train.iloc[:,47]
y

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20,random_state = 8)

# %%
from sklearn.preprocessing import StandardScaler #Standardization
func = StandardScaler()
func.fit(x_train)
transf_train = func.transform(x_train)
transf_test = func.transform(x_test)

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.linear_model import LinearRegression

spl = KFold(n_splits = 10)
model_1  = LinearRegression()
result = cross_val_score(model_1,x,y,cv = spl,scoring = 'neg_mean_absolute_error')
result

# %%
model_1.fit(x_train, y_train)

# %%
intercept = model_1.intercept_
coefficients = model_1.coef_

print('intercept:', model_1.intercept_)
print('coefficients:', model_1.coef_)

# %%
print('r-squared: ', model_1.score(x_train, y_train))
print('r-squared: ', model_1.score(x_test, y_test))

# %%
from sklearn.linear_model import SGDRegressor

model_2  = SGDRegressor(penalty='l1')
model_2.fit(x_train,y_train)

# %%
intercept = model_2.intercept_
coefficients = model_2.coef_

print('intercept:', model_2.intercept_)
print('coefficients:', model_2.coef_)

# %%
print('r-squared: ', model_2.score(x_train, y_train))
print('r-squared: ', model_2.score(x_test, y_test))

# %%
model_2.n_iter_

# %%
preds_2 = model_2.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,preds_2)

# %%
model_3  = SGDRegressor(penalty='l2')
model_3.fit(x_train,y_train)

# %%
intercept = model_3.intercept_
coefficients = model_3.coef_

print('intercept:', model_3.intercept_)
print('coefficients:', model_3.coef_)

# %%
print('r-squared: ', model_3.score(x_train, y_train))
print('r-squared: ', model_3.score(x_test, y_test))

# %%
preds_3 = model_3.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,preds_3)

# %%
model_4  = SGDRegressor(penalty='elasticnet')
model_4.fit(x_train,y_train)

# %%
intercept = model_4.intercept_
coefficients = model_4.coef_

print('intercept:', model_4.intercept_)
print('coefficients:', model_4.coef_)

# %%
print('r-squared: ', model_4.score(x_train, y_train))
print('r-squared: ', model_4.score(x_test, y_test))

# %%
preds_4 = model_4.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,preds_4)
